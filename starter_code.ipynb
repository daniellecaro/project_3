# %%
# import libraries
import os
import csv
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# read in files
diabetes_atlas = pd.read_csv("Resources/DiabetesAtlasData.csv")
food_access_atlas = pd.read_csv("Resources/food access research altas.csv")

# %%
# show column names diabetes atlas
diabetes_atlas_columns = diabetes_atlas.columns
diabetes_atlas_columns
# Out:
# Index(['Year', 'County_FIPS', 'County', 'State',
#        'Diagnosed Diabetes Percentage', 'Overall SVI'],
#       dtype='object')

# %%
# show column names diabetes atlas
food_access_atlas_columns = food_access_atlas.columns
food_access_atlas_columns
# Out:
# Index(['CensusTract', 'State', 'County', 'Urban', 'Pop2010', 'OHU2010',
#        'GroupQuartersFlag', 'NUMGQTRS', 'PCTGQTRS', 'LILATracts_1And10',
#        ...
#        'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI',
#        'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP'],
#       dtype='object', length=147)

# %%
# display diabetes_atlas df
diabetes_atlas.head()
# Out:
#    Year  County_FIPS          County    State  Diagnosed Diabetes Percentage  \
# 0  2018       1001.0  Autauga County  Alabama                            9.5
# 1  2018       1003.0  Baldwin County  Alabama                            8.4
# 2  2018       1005.0  Barbour County  Alabama                           13.5
# 3  2018       1007.0     Bibb County  Alabama                           10.2
# 4  2018       1009.0   Blount County  Alabama                           10.5
#
#    Overall SVI
# 0       0.4354
# 1       0.2162
# 2       0.9959
# 3       0.6003
# 4       0.4242

# %%
# display diabetes_atlas df
food_access_atlas.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %%
# check that every column has same count
diabetes_atlas.count()
# Out:
# Year                             3142
# County_FIPS                      3141
# County                           3141
# State                            3141
# Diagnosed Diabetes Percentage    3141
# Overall SVI                      3141
# dtype: int64

# %%
# check that every column has same count
food_access_atlas.count()
# Out:
# CensusTract      72531
# State            72531
# County           72531
# Urban            72531
# Pop2010          72531
#                  ...
# TractAIAN        72527
# TractOMultir     72527
# TractHispanic    72527
# TractHUNV        72527
# TractSNAP        72527
# Length: 147, dtype: int64

# %%
# see data types diabetes_atlas
diabetes_atlas.dtypes
# Out:
# Year                              object
# County_FIPS                      float64
# County                            object
# State                             object
# Diagnosed Diabetes Percentage    float64
# Overall SVI                      float64
# dtype: object

# %%
# see data types food_access_atlas
food_access_atlas.dtypes
# Out:
# CensusTract        int64
# State             object
# County            object
# Urban              int64
# Pop2010            int64
#                   ...
# TractAIAN        float64
# TractOMultir     float64
# TractHispanic    float64
# TractHUNV        float64
# TractSNAP        float64
# Length: 147, dtype: object

# %%
# Drop rows with any null values
# df.dropna(inplace=True)
# df = df.dropna(subset=['column_name'])    this will drop null values  in the column we  choose * for future ref if we need to get rid of null values *

# %%
# Group the food access df by county to prep for df merge
# grouped_df = food_access_atlas.groupby(food_access_atlas["County"])
# grouped_df

# %%
# Merge dfs on "County"
merged_df = pd.merge(diabetes_atlas, food_access_atlas, on=["County"])
merged_df
# Out:
#         Year  County_FIPS           County  State_x  \
# 0       2018       1001.0   Autauga County  Alabama
# 1       2018       1001.0   Autauga County  Alabama
# 2       2018       1001.0   Autauga County  Alabama
# 3       2018       1001.0   Autauga County  Alabama
# 4       2018       1001.0   Autauga County  Alabama
# ...      ...          ...              ...      ...
# 293722  2018      56043.0  Washakie County  Wyoming
# 293723  2018      56043.0  Washakie County  Wyoming
# 293724  2018      56043.0  Washakie County  Wyoming
# 293725  2018      56045.0    Weston County  Wyoming
# 293726  2018      56045.0    Weston County  Wyoming
#
#         Diagnosed Diabetes Percentage  Overall SVI  CensusTract  State_y  \
# 0                                 9.5       0.4354   1001020100  Alabama
# 1                                 9.5       0.4354   1001020200  Alabama
# 2                                 9.5       0.4354   1001020300  Alabama
# 3                                 9.5       0.4354   1001020400  Alabama
# 4                                 9.5       0.4354   1001020500  Alabama
# ...                               ...          ...          ...      ...
# 293722                            7.4       0.3732  56043000200  Wyoming
# 293723                            7.4       0.3732  56043000301  Wyoming
# 293724                            7.4       0.3732  56043000302  Wyoming
# 293725                            7.6       0.3475  56045951100  Wyoming
# 293726                            7.6       0.3475  56045951300  Wyoming
#
#         Urban  Pop2010  ...  TractSeniors  TractWhite  TractBlack  TractAsian  \
# 0           1     1912  ...         221.0      1622.0       217.0        14.0
# 1           1     2170  ...         214.0       888.0      1217.0         5.0
# 2           1     3373  ...         439.0      2576.0       647.0        17.0
# 3           1     4386  ...         904.0      4086.0       193.0        18.0
# 4           1    10766  ...        1126.0      8666.0      1437.0       296.0
# ...       ...      ...  ...           ...         ...         ...         ...
# 293722      0     3326  ...         593.0      3106.0         6.0        15.0
# 293723      1     2665  ...         399.0      2377.0         5.0        23.0
# 293724      1     2542  ...         516.0      2312.0        11.0        10.0
# 293725      0     3314  ...         499.0      3179.0        15.0        10.0
# 293726      1     3894  ...         650.0      3706.0         6.0        10.0
#
#         TractNHOPI  TractAIAN  TractOMultir  TractHispanic  TractHUNV  \
# 0              0.0       14.0          45.0           44.0        6.0
# 1              0.0        5.0          55.0           75.0       89.0
# 2              5.0       11.0         117.0           87.0       99.0
# 3              4.0       11.0          74.0           85.0       21.0
# 4              9.0       48.0         310.0          355.0      230.0
# ...            ...        ...           ...            ...        ...
# 293722         0.0       27.0         172.0          309.0       61.0
# 293723         0.0       40.0         220.0          446.0       88.0
# 293724         1.0       26.0         182.0          407.0       23.0
# 293725         1.0       47.0          62.0           91.0       47.0
# 293726         2.0       44.0         126.0          125.0       34.0
#
#         TractSNAP
# 0           102.0
# 1           156.0
# 2           172.0
# 3            98.0
# 4           339.0
# ...           ...
# 293722       64.0
# 293723       41.0
# 293724       64.0
# 293725       34.0
# 293726      110.0
#
# [293727 rows x 152 columns]

# %%
#Drop extra state column
merged_df = merged_df.drop(columns=["State_y"])
merged_df
# Out:
#         Year  County_FIPS           County  State_x  \
# 0       2018       1001.0   Autauga County  Alabama
# 1       2018       1001.0   Autauga County  Alabama
# 2       2018       1001.0   Autauga County  Alabama
# 3       2018       1001.0   Autauga County  Alabama
# 4       2018       1001.0   Autauga County  Alabama
# ...      ...          ...              ...      ...
# 293722  2018      56043.0  Washakie County  Wyoming
# 293723  2018      56043.0  Washakie County  Wyoming
# 293724  2018      56043.0  Washakie County  Wyoming
# 293725  2018      56045.0    Weston County  Wyoming
# 293726  2018      56045.0    Weston County  Wyoming
#
#         Diagnosed Diabetes Percentage  Overall SVI  CensusTract  Urban  \
# 0                                 9.5       0.4354   1001020100      1
# 1                                 9.5       0.4354   1001020200      1
# 2                                 9.5       0.4354   1001020300      1
# 3                                 9.5       0.4354   1001020400      1
# 4                                 9.5       0.4354   1001020500      1
# ...                               ...          ...          ...    ...
# 293722                            7.4       0.3732  56043000200      0
# 293723                            7.4       0.3732  56043000301      1
# 293724                            7.4       0.3732  56043000302      1
# 293725                            7.6       0.3475  56045951100      0
# 293726                            7.6       0.3475  56045951300      1
#
#         Pop2010  OHU2010  ...  TractSeniors  TractWhite  TractBlack  \
# 0          1912      693  ...         221.0      1622.0       217.0
# 1          2170      743  ...         214.0       888.0      1217.0
# 2          3373     1256  ...         439.0      2576.0       647.0
# 3          4386     1722  ...         904.0      4086.0       193.0
# 4         10766     4082  ...        1126.0      8666.0      1437.0
# ...         ...      ...  ...           ...         ...         ...
# 293722     3326     1317  ...         593.0      3106.0         6.0
# 293723     2665     1154  ...         399.0      2377.0         5.0
# 293724     2542     1021  ...         516.0      2312.0        11.0
# 293725     3314     1322  ...         499.0      3179.0        15.0
# 293726     3894     1699  ...         650.0      3706.0         6.0
#
#         TractAsian  TractNHOPI  TractAIAN  TractOMultir  TractHispanic  \
# 0             14.0         0.0       14.0          45.0           44.0
# 1              5.0         0.0        5.0          55.0           75.0
# 2             17.0         5.0       11.0         117.0           87.0
# 3             18.0         4.0       11.0          74.0           85.0
# 4            296.0         9.0       48.0         310.0          355.0
# ...            ...         ...        ...           ...            ...
# 293722        15.0         0.0       27.0         172.0          309.0
# 293723        23.0         0.0       40.0         220.0          446.0
# 293724        10.0         1.0       26.0         182.0          407.0
# 293725        10.0         1.0       47.0          62.0           91.0
# 293726        10.0         2.0       44.0         126.0          125.0
#
#         TractHUNV  TractSNAP
# 0             6.0      102.0
# 1            89.0      156.0
# 2            99.0      172.0
# 3            21.0       98.0
# 4           230.0      339.0
# ...           ...        ...
# 293722       61.0       64.0
# 293723       88.0       41.0
# 293724       23.0       64.0
# 293725       47.0       34.0
# 293726       34.0      110.0
#
# [293727 rows x 151 columns]

# %%
merged_df.dtypes
# Out:
# Year                              object
# County_FIPS                      float64
# County                            object
# State_x                           object
# Diagnosed Diabetes Percentage    float64
#                                   ...
# TractAIAN                        float64
# TractOMultir                     float64
# TractHispanic                    float64
# TractHUNV                        float64
# TractSNAP                        float64
# Length: 151, dtype: object

# %%
print(merged_df.columns.tolist())
# Out:
# ['Year', 'County_FIPS', 'County', 'State_x', 'Diagnosed Diabetes Percentage', 'Overall SVI', 'CensusTract', 'Urban', 'Pop2010', 'OHU2010', 'GroupQuartersFlag', 'NUMGQTRS', 'PCTGQTRS', 'LILATracts_1And10', 'LILATracts_halfAnd10', 'LILATracts_1And20', 'LILATracts_Vehicle', 'HUNVFlag', 'LowIncomeTracts', 'PovertyRate', 'MedianFamilyIncome', 'LA1and10', 'LAhalfand10', 'LA1and20', 'LATracts_half', 'LATracts1', 'LATracts10', 'LATracts20', 'LATractsVehicle_20', 'LAPOP1_10', 'LAPOP05_10', 'LAPOP1_20', 'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'lapophalf', 'lapophalfshare', 'lalowihalf', 'lalowihalfshare', 'lakidshalf', 'lakidshalfshare', 'laseniorshalf', 'laseniorshalfshare', 'lawhitehalf', 'lawhitehalfshare', 'lablackhalf', 'lablackhalfshare', 'laasianhalf', 'laasianhalfshare', 'lanhopihalf', 'lanhopihalfshare', 'laaianhalf', 'laaianhalfshare', 'laomultirhalf', 'laomultirhalfshare', 'lahisphalf', 'lahisphalfshare', 'lahunvhalf', 'lahunvhalfshare', 'lasnaphalf', 'lasnaphalfshare', 'lapop1', 'lapop1share', 'lalowi1', 'lalowi1share', 'lakids1', 'lakids1share', 'laseniors1', 'laseniors1share', 'lawhite1', 'lawhite1share', 'lablack1', 'lablack1share', 'laasian1', 'laasian1share', 'lanhopi1', 'lanhopi1share', 'laaian1', 'laaian1share', 'laomultir1', 'laomultir1share', 'lahisp1', 'lahisp1share', 'lahunv1', 'lahunv1share', 'lasnap1', 'lasnap1share', 'lapop10', 'lapop10share', 'lalowi10', 'lalowi10share', 'lakids10', 'lakids10share', 'laseniors10', 'laseniors10share', 'lawhite10', 'lawhite10share', 'lablack10', 'lablack10share', 'laasian10', 'laasian10share', 'lanhopi10', 'lanhopi10share', 'laaian10', 'laaian10share', 'laomultir10', 'laomultir10share', 'lahisp10', 'lahisp10share', 'lahunv10', 'lahunv10share', 'lasnap10', 'lasnap10share', 'lapop20', 'lapop20share', 'lalowi20', 'lalowi20share', 'lakids20', 'lakids20share', 'laseniors20', 'laseniors20share', 'lawhite20', 'lawhite20share', 'lablack20', 'lablack20share', 'laasian20', 'laasian20share', 'lanhopi20', 'lanhopi20share', 'laaian20', 'laaian20share', 'laomultir20', 'laomultir20share', 'lahisp20', 'lahisp20share', 'lahunv20', 'lahunv20share', 'lasnap20', 'lasnap20share', 'TractLOWI', 'TractKids', 'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP']

# %%
merged_df.count()
# Out:
# Year                             293727
# County_FIPS                      293727
# County                           293727
# State_x                          293727
# Diagnosed Diabetes Percentage    293727
#                                   ...
# TractAIAN                        293723
# TractOMultir                     293723
# TractHispanic                    293723
# TractHUNV                        293723
# TractSNAP                        293723
# Length: 151, dtype: int64

# %%
# Rename columns
# merged_df['Year', 'County_FIPS', 'County', 'State', 'Diagnosed Diabetes Percentage', 'Overall SVI', 'CensusTract', 'Urban', 'Pop2010', 'OHU2010', 'GroupQuartersFlag', 'NUMGQTRS', 'PCTGQTRS', 'LILATracts_1And10', 'LILATracts_halfAnd10', 'LILATracts_1And20', 'LILATracts_Vehicle', 'HUNVFlag', 'LowIncomeTracts', 'PovertyRate', 'MedianFamilyIncome', 'LA1and10', 'LAhalfand10', 'LA1and20', 'LATracts_half', 'LATracts1', 'LATracts10', 'LATracts20', 'LATractsVehicle_20', 'LAPOP1_10', 'LAPOP05_10', 'LAPOP1_20', 'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'lapophalf', 'lapophalfshare', 'lalowihalf', 'lalowihalfshare', 'lakidshalf', 'lakidshalfshare', 'laseniorshalf', 'laseniorshalfshare', 'lawhitehalf', 'lawhitehalfshare', 'lablackhalf', 'lablackhalfshare', 'laasianhalf', 'laasianhalfshare', 'lanhopihalf', 'lanhopihalfshare', 'laaianhalf', 'laaianhalfshare', 'laomultirhalf', 'laomultirhalfshare', 'lahisphalf', 'lahisphalfshare', 'lahunvhalf', 'lahunvhalfshare', 'lasnaphalf', 'lasnaphalfshare', 'lapop1', 'lapop1share', 'lalowi1', 'lalowi1share', 'lakids1', 'lakids1share', 'laseniors1', 'laseniors1share', 'lawhite1', 'lawhite1share', 'lablack1', 'lablack1share', 'laasian1', 'laasian1share', 'lanhopi1', 'lanhopi1share', 'laaian1', 'laaian1share', 'laomultir1', 'laomultir1share', 'lahisp1', 'lahisp1share', 'lahunv1', 'lahunv1share', 'lasnap1', 'lasnap1share', 'lapop10', 'lapop10share', 'lalowi10', 'lalowi10share', 'lakids10', 'lakids10share', 'laseniors10', 'laseniors10share', 'lawhite10', 'lawhite10share', 'lablack10', 'lablack10share', 'laasian10', 'laasian10share', 'lanhopi10', 'lanhopi10share', 'laaian10', 'laaian10share', 'laomultir10', 'laomultir10share', 'lahisp10', 'lahisp10share', 'lahunv10', 'lahunv10share', 'lasnap10', 'lasnap10share', 'lapop20', 'lapop20share', 'lalowi20', 'lalowi20share', 'lakids20', 'lakids20share', 'laseniors20', 'laseniors20share', 'lawhite20', 'lawhite20share', 'lablack20', 'lablack20share', 'laasian20', 'laasian20share', 'lanhopi20', 'lanhopi20share', 'laaian20', 'laaian20share', 'laomultir20', 'laomultir20share', 'lahisp20', 'lahisp20share', 'lahunv20', 'lahunv20share', 'lasnap20', 'lasnap20share', 'TractLOWI', 'TractKids', 'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP']
